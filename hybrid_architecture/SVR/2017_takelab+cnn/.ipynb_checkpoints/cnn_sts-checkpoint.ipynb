# %%
import numpy as np
import multiprocessing as mp
import random,copy,string
from nltk.tokenize import word_tokenize
from scipy.stats import pearsonr
from tensorflow.python.keras import backend as K
from tensorflow.python.keras.models import Model
from tensorflow.python.keras.layers import Input, Convolution1D, MaxPooling1D, Flatten
from tensorflow.python.keras.layers import Lambda, multiply, concatenate, Dense
from tensorflow.python.keras.regularizers import l2
from tensorflow.python.keras.callbacks import Callback
from tensorflow.python.keras.preprocessing.sequence import pad_sequences

class Embedder(object):
    def __init__(self, dictname, wordvectdim):
        print('Loading GloVe...(This might take one or two minutes.)')
        self.wordtoindex   = dict()
        self.indextovector = []
        self.indextovector.append(np.zeros(wordvectdim))
        lines = open(dictname, 'r').readlines()
        blocksize = 1000
        r_list = mp.Pool(32).map(self._worker, ((lines[block:block+blocksize], block) for block in range(0,len(lines),blocksize)))
        for r in r_list:
          self.wordtoindex.update(r[0])
          self.indextovector.extend(r[1])
        self.indextovector = np.array(self.indextovector, dtype='float32')
    def _worker(self,args):
        wordtoindex   = dict()
        indextovector = []
        for line in args[0]:
            elements = line.split(' ')
            wordtoindex[elements[0]] = len(indextovector)+args[1]+1
            indextovector.append(np.array(elements[1:]).astype(float))
        return (wordtoindex,indextovector)
    def matrixize(self, sentencelist, sentencepad):
        indexlist = []
        for sentence in sentencelist:
            indexes = []
            for word in sentence:
                word = word.lower()
                if word not in self.wordtoindex: indexes.append(1)
                else: indexes.append(self.wordtoindex[word])
            indexlist.append(indexes)
        return self.indextovector[(pad_sequences(indexlist, maxlen=sentencepad, truncating='post', padding='post'))]

class STSTask():
    def __init__(self, c):
        self.c = c
    def load_resc(self,dictname):
        self.embed = Embedder(dictname, self.c['wordvectdim'])
    def load_data(self, trainfile, validfile, testfile):
        self.traindata= self._load_data(trainfile)
        self.validdata= self._load_data(validfile)
        self.testdata = self._load_data(testfile)
    def _load_data(self, filename):
        s0,s1,labels = [],[],[]
        lines=open(filename,'r').read().splitlines()
        for line in lines:
            _,_,_,_, label, s0x, s1x = line.rstrip().split('\t')[:7]
            labels.append(float(label))
            s0.append([word.lower() for word in word_tokenize(s0x) if word not in string.punctuation])
            s1.append([word.lower() for word in word_tokenize(s1x) if word not in string.punctuation])
        m0 = self.embed.matrixize(s0, self.c['sentencepad'])
        m1 = self.embed.matrixize(s1, self.c['sentencepad'])
        classes = np.zeros((len(labels), self.c['num_classes']))
        for i, label in enumerate(labels):
            if np.floor(label) + 1 < self.c['num_classes']:
                classes[i, int(np.floor(label)) + 1] = label - np.floor(label)
            classes[i, int(np.floor(label))] = np.floor(label) - label + 1
        return {'labels': labels, 's0': s0, 's1': s1, 'classes': classes, 'm0': m0, 'm1': m1}

    def create_model(self):
        K.clear_session()
        input0 = Input(shape=(self.c['sentencepad'], self.c['wordvectdim']))
        input1 = Input(shape=(self.c['sentencepad'], self.c['wordvectdim']))
        Convolt_Layer=[]
        MaxPool_Layer=[]
        Flatten_Layer=[]
        for kernel_size, filters in self.c['cnnfilters'].items():
            Convolt_Layer.append(Convolution1D(filters=filters,
                                               kernel_size=kernel_size,
                                               padding='valid',
                                               activation=self.c['cnnactivate'],
                                               kernel_initializer=self.c['cnninitial']))
            MaxPool_Layer.append(MaxPooling1D(pool_size=int(self.c['sentencepad']-kernel_size+1)))
            Flatten_Layer.append(Flatten())
        Convolted_tensor0=[]
        Convolted_tensor1=[]
        for channel in range(len(self.c['cnnfilters'])):
            print("inside convo: ")
            print(input0.shape)
            print(input1.shape)
            Convolted_tensor0.append(Convolt_Layer[channel](input0))
            Convolted_tensor1.append(Convolt_Layer[channel](input1))
            print(Convolt_Layer[channel](input0).shape)
            print(Convolt_Layer[channel](input1).shape)
        MaxPooled_tensor0=[]
        MaxPooled_tensor1=[]
        for channel in range(len(self.c['cnnfilters'])):
            print("inside max")
            MaxPooled_tensor0.append(MaxPool_Layer[channel](Convolted_tensor0[channel]))
            MaxPooled_tensor1.append(MaxPool_Layer[channel](Convolted_tensor1[channel]))
            print(MaxPool_Layer[channel](Convolted_tensor0[channel]).shape)
            print(MaxPool_Layer[channel](Convolted_tensor1[channel]).shape)
            
        Flattened_tensor0=[]
        Flattened_tensor1=[]
        for channel in range(len(self.c['cnnfilters'])):
            Flattened_tensor0.append(Flatten_Layer[channel](MaxPooled_tensor0[channel]))
            Flattened_tensor1.append(Flatten_Layer[channel](MaxPooled_tensor1[channel]))
            print("inside flat")
            print(Flatten_Layer[channel](MaxPooled_tensor0[channel]).shape)
            print(Flatten_Layer[channel](MaxPooled_tensor1[channel]).shape)
            
        if len(self.c['cnnfilters']) > 1:
            Flattened_tensor0=concatenate(Flattened_tensor0)
            Flattened_tensor1=concatenate(Flattened_tensor1)
        else:
            Flattened_tensor0=Flattened_tensor0[0]
            Flattened_tensor1=Flattened_tensor1[0]
            
        absDifference = Lambda(lambda X:K.abs(X[0] - X[1]))([Flattened_tensor0,Flattened_tensor1])
        
        mulDifference = multiply([Flattened_tensor0,Flattened_tensor1])
        allDifference = concatenate([absDifference,mulDifference])
        print(mulDifference.shape)
        print(allDifference.shape)
        for ilayer, densedimension in enumerate(self.c['densedimension']):
            allDifference = Dense(units=int(densedimension), 
                                  activation=self.c['denseactivate'], 
                                  kernel_initializer=self.c['denseinitial'])(allDifference)
            print("inside dense")
            print(allDifference.shape)
        output = Dense(name='output',
                       units=self.c['num_classes'],
                       activation='softmax', 
                       kernel_initializer=self.c['denseinitial'])(allDifference)
        print("kd")
        print(output.shape)
        self.model = Model(inputs=[input0,input1], outputs=output)
        self.model.compile(loss={'output': self._lossfunction}, optimizer=self.c['optimizer'])
    def _lossfunction(self,y_true,y_pred):
        ny_true = y_true[:,1] + 2*y_true[:,2] + 3*y_true[:,3] + 4*y_true[:,4] + 5*y_true[:,5]
        ny_pred = y_pred[:,1] + 2*y_pred[:,2] + 3*y_pred[:,3] + 4*y_pred[:,4] + 5*y_pred[:,5]
        my_true = K.mean(ny_true)
        my_pred = K.mean(ny_pred)
        var_true = (ny_true - my_true)**2
        var_pred = (ny_pred - my_pred)**2
        return -K.sum((ny_true-my_true)*(ny_pred-my_pred),axis=-1) / (K.sqrt(K.sum(var_true,axis=-1)*K.sum(var_pred,axis=-1)))

    def eval_model(self):
        results = []
        for data in [self.traindata, self.validdata, self.testdata ]:
            predictionclasses = []
            for dataslice,_ in self._sample_pairs(data, len(data['classes']), shuffle=False, once=True):
                
                predictionclasses += list(self.model.predict(dataslice))
            prediction = np.dot(np.array(predictionclasses),np.arange(self.c['num_classes']))
            goldlabels = data['labels']
            result=pearsonr(prediction, goldlabels)[0]
            results.append(round(result,4))
        print('[Train, Valid, Test]=',end='')
        print(results)
        return tuple(results)
    
    def eval_model1(self):
        results = []
        for data in [self.testdata]:
            predictionclasses = []
            for dataslice,_ in self._sample_pairs(data, len(data['classes']), shuffle=False, once=True):
                predictionclasses += list(self.model.predict(dataslice))
            prediction = np.dot(np.array(predictionclasses),np.arange(self.c['num_classes']))
            goldlabels = data['labels']
            result=pearsonr(prediction, goldlabels)[0]
            results.append(round(result,4))
        print('[Test]=',end='')
        print(results)
        return (results,prediction)
    
    def eval_model2(self):
        results = []
        for data in [self.traindata]:
            predictionclasses = []
            for dataslice,_ in self._sample_pairs(data, len(data['classes']), shuffle=False, once=True):
                predictionclasses += list(self.model.predict(dataslice))
            prediction = np.dot(np.array(predictionclasses),np.arange(self.c['num_classes']))
            goldlabels = data['labels']
            result=pearsonr(prediction, goldlabels)[0]
            results.append(round(result,4))
        print('[Test]=',end='')
        print(results)
        return (results,prediction)
    
    def fit_model(self, wfname):
        kwargs = dict()
        kwargs['generator']       = self._sample_pairs(self.traindata, self.c['batch_size'])
        kwargs['steps_per_epoch'] = self.c['num_batchs']
        kwargs['epochs']          = self.c['num_epochs']
        class Evaluate(Callback):
            def __init__(self, task, wfname):
                self.task       = task
                self.bestresult = 0.0
                self.wfname     = wfname
            def on_epoch_end(self, epoch, logs={}):
                print("Inside On epoch end")
                _,validresult = self.task.eval_model()
                if validresult > self.bestresult:
                    self.bestresult = validresult
                    self.task.model.save(self.wfname)
        kwargs['callbacks'] = [Evaluate(self, wfname)]
        return self.model.fit_generator(verbose=1,**kwargs)
    def _sample_pairs(self, data, batch_size, shuffle=True, once=False):
        #print("shuffle= ",shuffle)
        #print("once= ",once)
        num = len(data['classes'])
        #print("num or len(data['classes'])= ",num)
        idN = int((num+batch_size-1) / batch_size)
        #print("batch_size",batch_size)
        #print("idN= ",idN)
        ids = list(range(num))
        #print("ids= ",ids)
        c=0
        while True:
            if shuffle: random.shuffle(ids)
            c=c+1
            print("counter",c)
            datacopy= copy.deepcopy(data)
            for name, value in datacopy.items():
                valuer=copy.copy(value)
                for i in range(num):
                    valuer[i]=value[ids[i]]
                datacopy[name] = valuer
            for i in range(idN):
                sl  = slice(i*batch_size, (i+1)*batch_size)
                print("sl", sl)
                dataslice= dict()
                for name, value in datacopy.items():
                    dataslice[name] = value[sl]
                x = [dataslice['m0'],dataslice['m1']]
                y = dataslice['classes']
                yield (x,y)
            if once: break

c = dict()
c['num_runs']   = 3
c['num_epochs'] = 64
c['num_batchs'] = 2
c['batch_size'] = 3000
c['wordvectdim']  = 300
c['sentencepad']  = 60
c['num_classes']  = 6
c['cnnfilters']     = {1: 1800}
c['cnninitial']     = 'he_uniform'
c['cnnactivate']    = 'relu'
c['densedimension'] = list([1800])
c['denseinitial']   = 'he_uniform'
c['denseactivate']  = 'tanh'
c['optimizer']  = 'adam'

if __name__ == "__main__":
    tsk = STSTask(c)
    tsk.load_resc('glove.840B.300d.txt')
    tsk.load_data('sts-train.csv', 'sts-dev.csv', 'sts-test.csv')
    bestresult = 0.0
    bestwfname = None
    for i_run in range(tsk.c['num_runs']):
        print('RunID: %s' %i_run)
        tsk.create_model()
        print('Training')   
        wfname = './weightfile'+str(i_run)
        tsk.fit_model(wfname)
        print('Prediction(best valid epoch)')
        tsk.model.load_weights(wfname)
        _,validresult = tsk.eval_model() 
        if validresult>bestresult:
            bestresult = validresult
            bestwfname = wfname
    print('Prediction(best run)', bestwfname)
    tsk.model.load_weights(bestwfname)
    tsk.eval_model()
# Out:
# Loading GloVe...(This might take one or two minutes.)
# RunID: 0
# inside convo:
# (?, 60, 300)
# (?, 60, 300)
# WARNING:tensorflow:From /apps/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# (?, 60, 1800)
# (?, 60, 1800)
# inside max
# (?, 1, 1800)
# (?, 1, 1800)
# inside flat
# (?, 1800)
# (?, 1800)
# (?, 1800)
# (?, 3600)
# inside dense
# (?, 1800)
# kd
# (?, 6)
# Training
# Epoch 1/64
# counter 1
# sl slice(0, 3000, None)
# sl slice(3000, 6000, None)
# counter 2
# WARNING:tensorflow:From /apps/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/ops/math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# sl slice(0, 3000, None)
# sl slice(3000, 6000, None)
# counter 3
# 1/2 [==============>...............] - ETA: 22s - loss: -0.1555Inside On epoch end
# counter 1
# sl slice(0, 3000, None)
# sl slice(3000, 6000, None)
# counter 4
# sl slice(0, 5749, None)
# counter 1
# sl slice(0, 1500, None)
# sl slice(0, 3000, None)
# sl slice(3000, 6000, None)
# counter 5
# [Train, Valid]=[0.6144, 0.6836]
# 2/2 [==============================] - 34s 17s/step - loss: -0.2911
# Epoch 2/64
# sl slice(0, 3000, None)
# sl slice(3000, 6000, None)
# counter 6
# 1/2 [==============>...............] - ETA: 10s - loss: -0.6105Inside On epoch end
# counter 1
# sl slice(0, 5749, None)
# sl slice(0, 3000, None)
# sl slice(3000, 6000, None)
# counter 7
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.5855, 0.647]
# 2/2 [==============================] - 20s 10s/step - loss: -0.5856
# Epoch 3/64
# sl slice(0, 3000, None)
# sl slice(3000, 6000, None)
# counter 8
# 1/2 [==============>...............] - ETA: 5s - loss: -0.5791Inside On epoch end
# counter 1
# sl slice(0, 5749, None)
# sl slice(0, 3000, None)
# sl slice(3000, 6000, None)
# counter 9
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.6292, 0.6773]
# 2/2 [==============================] - 13s 7s/step - loss: -0.5992
# Epoch 4/64
# sl slice(0, 3000, None)
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 4s - loss: -0.6230counter 10
# Inside On epoch end
# counter 1
# sl slice(0, 5749, None)
# sl slice(0, 3000, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.6302, 0.6642]
# 2/2 [==============================] - 13s 6s/step - loss: -0.6260
# Epoch 5/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 3s - loss: -0.6364counter 11
# Inside On epoch end
# counter 1
# sl slice(0, 5749, None)
# sl slice(0, 3000, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.6481, 0.675]
# 2/2 [==============================] - 11s 5s/step - loss: -0.6315
# Epoch 6/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 3s - loss: -0.6543counter 12
# Inside On epoch end
# counter 1
# sl slice(0, 5749, None)
# sl slice(0, 3000, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.6629, 0.6918]
# 2/2 [==============================] - 11s 6s/step - loss: -0.6517
# Epoch 7/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 3s - loss: -0.6497counter 13
# Inside On epoch end
# counter 1
# sl slice(0, 5749, None)
# sl slice(0, 3000, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.6717, 0.6998]
# 2/2 [==============================] - 11s 6s/step - loss: -0.6651
# Epoch 8/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 3s - loss: -0.6784counter 14
# Inside On epoch end
# counter 1
# sl slice(0, 5749, None)
# sl slice(0, 3000, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.6851, 0.7037]
# 2/2 [==============================] - 12s 6s/step - loss: -0.6741
# Epoch 9/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 3s - loss: -0.6885counter 15
# Inside On epoch end
# counter 1
# sl slice(0, 5749, None)
# sl slice(0, 3000, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.6972, 0.7065]
# 2/2 [==============================] - 12s 6s/step - loss: -0.6877
# Epoch 10/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 3s - loss: -0.6923counter 16
# Inside On epoch end
# counter 1
# sl slice(0, 3000, None)
# sl slice(0, 5749, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.7069, 0.7097]
# 2/2 [==============================] - 13s 6s/step - loss: -0.6992
# Epoch 11/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 3s - loss: -0.7016counter 17
# Inside On epoch end
# counter 1
# sl slice(0, 3000, None)
# sl slice(0, 5749, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.7166, 0.7163]
# 2/2 [==============================] - 11s 6s/step - loss: -0.7090
# Epoch 12/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 3s - loss: -0.7112counter 18
# Inside On epoch end
# counter 1
# sl slice(0, 3000, None)
# sl slice(0, 5749, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.7238, 0.7211]
# 2/2 [==============================] - 11s 6s/step - loss: -0.7182
# Epoch 13/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 3s - loss: -0.7302counter 19
# Inside On epoch end
# counter 1
# sl slice(0, 5749, None)
# sl slice(0, 3000, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.731, 0.7253]
# 2/2 [==============================] - 12s 6s/step - loss: -0.7254
# Epoch 14/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 3s - loss: -0.7321counter 20
# Inside On epoch end
# counter 1
# sl slice(0, 3000, None)
# sl slice(0, 5749, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.7374, 0.7289]
# 2/2 [==============================] - 14s 7s/step - loss: -0.7322
# Epoch 15/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 6s - loss: -0.7378counter 21
# Inside On epoch end
# counter 1
# sl slice(0, 5749, None)
# sl slice(0, 3000, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.7449, 0.7355]
# 2/2 [==============================] - 15s 7s/step - loss: -0.7390
# Epoch 16/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 2s - loss: -0.7404counter 22
# Inside On epoch end
# counter 1
# sl slice(0, 5749, None)
# sl slice(0, 3000, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.752, 0.7414]
# 2/2 [==============================] - 11s 6s/step - loss: -0.7468
# Epoch 17/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 3s - loss: -0.7470counter 23
# Inside On epoch end
# counter 1
# sl slice(0, 5749, None)
# sl slice(0, 3000, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.7598, 0.7459]
# 2/2 [==============================] - 12s 6s/step - loss: -0.7538
# Epoch 18/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 3s - loss: -0.7716counter 24
# Inside On epoch end
# counter 1
# sl slice(0, 5749, None)
# sl slice(0, 3000, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.7675, 0.7523]
# 2/2 [==============================] - 12s 6s/step - loss: -0.7605
# Epoch 19/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 3s - loss: -0.7663counter 25
# Inside On epoch end
# counter 1
# sl slice(0, 5749, None)
# sl slice(0, 3000, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.7755, 0.762]
# 2/2 [==============================] - 13s 6s/step - loss: -0.7695
# Epoch 20/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 3s - loss: -0.7711counter 26
# Inside On epoch end
# counter 1
# sl slice(0, 5749, None)
# sl slice(0, 3000, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.7849, 0.7651]
# 2/2 [==============================] - 12s 6s/step - loss: -0.7784
# Epoch 21/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 3s - loss: -0.7798counter 27
# Inside On epoch end
# counter 1
# sl slice(0, 5749, None)
# sl slice(0, 3000, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.7954, 0.7768]
# 2/2 [==============================] - 13s 7s/step - loss: -0.7863
# Epoch 22/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 3s - loss: -0.7963counter 28
# Inside On epoch end
# counter 1
# sl slice(0, 5749, None)
# sl slice(0, 3000, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.7988, 0.7847]
# 2/2 [==============================] - 13s 7s/step - loss: -0.7969
# Epoch 23/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 3s - loss: -0.8030counter 29
# Inside On epoch end
# counter 1
# sl slice(0, 3000, None)
# sl slice(0, 5749, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.8018, 0.7857]
# 2/2 [==============================] - 13s 6s/step - loss: -0.7945
# Epoch 24/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 3s - loss: -0.8025counter 30
# Inside On epoch end
# counter 1
# sl slice(0, 5749, None)
# sl slice(0, 3000, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.8198, 0.7844]
# 2/2 [==============================] - 12s 6s/step - loss: -0.8092
# Epoch 25/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 3s - loss: -0.8223counter 31
# Inside On epoch end
# counter 1
# sl slice(0, 5749, None)
# sl slice(0, 3000, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.832, 0.7977]
# 2/2 [==============================] - 13s 6s/step - loss: -0.8228
# Epoch 26/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 3s - loss: -0.8277counter 32
# Inside On epoch end
# counter 1
# sl slice(0, 5749, None)
# sl slice(0, 3000, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.8406, 0.8015]
# 2/2 [==============================] - 12s 6s/step - loss: -0.8321
# Epoch 27/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 3s - loss: -0.8357counter 33
# Inside On epoch end
# counter 1
# sl slice(0, 5749, None)
# sl slice(0, 3000, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.8445, 0.7911]
# 2/2 [==============================] - 11s 5s/step - loss: -0.8415
# Epoch 28/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 2s - loss: -0.8354counter 34
# Inside On epoch end
# counter 1
# sl slice(0, 5749, None)
# sl slice(0, 3000, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.8594, 0.8088]
# 2/2 [==============================] - 12s 6s/step - loss: -0.8485
# Epoch 29/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 3s - loss: -0.8563counter 35
# Inside On epoch end
# counter 1
# sl slice(0, 5749, None)
# sl slice(0, 3000, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.8688, 0.8108]
# 2/2 [==============================] - 12s 6s/step - loss: -0.8603
# Epoch 30/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 3s - loss: -0.8658counter 36
# Inside On epoch end
# counter 1
# sl slice(0, 5749, None)
# sl slice(0, 3000, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.8795, 0.8064]
# 2/2 [==============================] - 12s 6s/step - loss: -0.8715
# Epoch 31/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 3s - loss: -0.8810counter 37
# Inside On epoch end
# counter 1
# sl slice(0, 5749, None)
# sl slice(0, 3000, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.8887, 0.8131]
# 2/2 [==============================] - 12s 6s/step - loss: -0.8814
# Epoch 32/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 3s - loss: -0.8866counter 38
# Inside On epoch end
# counter 1
# sl slice(0, 5749, None)
# sl slice(0, 3000, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.8933, 0.8051]
# 2/2 [==============================] - 12s 6s/step - loss: -0.8902
# Epoch 33/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 3s - loss: -0.8931counter 39
# Inside On epoch end
# counter 1
# sl slice(0, 5749, None)
# sl slice(0, 3000, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.8924, 0.8035]
# 2/2 [==============================] - 12s 6s/step - loss: -0.8916
# Epoch 34/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 3s - loss: -0.8959counter 40
# Inside On epoch end
# counter 1
# sl slice(0, 3000, None)
# sl slice(0, 5749, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.9143, 0.8025]
# 2/2 [==============================] - 13s 7s/step - loss: -0.8995
# Epoch 35/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 3s - loss: -0.9135counter 41
# Inside On epoch end
# counter 1
# sl slice(0, 5749, None)
# sl slice(0, 3000, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.9187, 0.7979]
# 2/2 [==============================] - 13s 6s/step - loss: -0.9136
# Epoch 36/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 3s - loss: -0.9203counter 42
# Inside On epoch end
# counter 1
# sl slice(0, 5749, None)
# sl slice(0, 3000, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.9288, 0.7979]
# 2/2 [==============================] - 12s 6s/step - loss: -0.9223
# Epoch 37/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 3s - loss: -0.9334counter 43
# Inside On epoch end
# counter 1
# sl slice(0, 5749, None)
# sl slice(0, 3000, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.9368, 0.8061]
# 2/2 [==============================] - 12s 6s/step - loss: -0.9297
# Epoch 38/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 3s - loss: -0.9367counter 44
# Inside On epoch end
# counter 1
# sl slice(0, 5749, None)
# sl slice(0, 3000, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.9395, 0.8117]
# 2/2 [==============================] - 11s 6s/step - loss: -0.9369
# Epoch 39/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 3s - loss: -0.9377counter 45
# Inside On epoch end
# counter 1
# sl slice(0, 5749, None)
# sl slice(0, 3000, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.9433, 0.7858]
# 2/2 [==============================] - 12s 6s/step - loss: -0.9427
# Epoch 40/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 3s - loss: -0.9445counter 46
# Inside On epoch end
# counter 1
# sl slice(0, 5749, None)
# sl slice(0, 3000, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.9518, 0.8092]
# 2/2 [==============================] - 12s 6s/step - loss: -0.9449
# Epoch 41/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 3s - loss: -0.9556counter 47
# Inside On epoch end
# counter 1
# sl slice(0, 5749, None)
# sl slice(0, 3000, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.9555, 0.8085]
# 2/2 [==============================] - 12s 6s/step - loss: -0.9501
# Epoch 42/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 3s - loss: -0.9567counter 48
# Inside On epoch end
# counter 1
# sl slice(0, 5749, None)
# sl slice(0, 3000, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.9375, 0.7858]
# 2/2 [==============================] - 12s 6s/step - loss: -0.9462
# Epoch 43/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 3s - loss: -0.9397counter 49
# Inside On epoch end
# counter 1
# sl slice(0, 5749, None)
# sl slice(0, 3000, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.9332, 0.8124]
# 2/2 [==============================] - 12s 6s/step - loss: -0.9363
# Epoch 44/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 3s - loss: -0.9368counter 50
# Inside On epoch end
# counter 1
# sl slice(0, 5749, None)
# sl slice(0, 3000, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.9398, 0.8143]
# 2/2 [==============================] - 12s 6s/step - loss: -0.9238
# Epoch 45/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 3s - loss: -0.9379counter 51
# Inside On epoch end
# counter 1
# sl slice(0, 5749, None)
# sl slice(0, 3000, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.9364, 0.707]
# 2/2 [==============================] - 12s 6s/step - loss: -0.9454
# Epoch 46/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 3s - loss: -0.9343counter 52
# Inside On epoch end
# counter 1
# sl slice(0, 5749, None)
# sl slice(0, 3000, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.9456, 0.8068]
# 2/2 [==============================] - 12s 6s/step - loss: -0.9498
# Epoch 47/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 3s - loss: -0.9439counter 53
# Inside On epoch end
# counter 1
# sl slice(0, 5749, None)
# sl slice(0, 3000, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.9537, 0.7937]
# 2/2 [==============================] - 12s 6s/step - loss: -0.9478
# Epoch 48/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 3s - loss: -0.9550counter 54
# Inside On epoch end
# counter 1
# sl slice(0, 5749, None)
# sl slice(0, 3000, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.9693, 0.8087]
# 2/2 [==============================] - 12s 6s/step - loss: -0.9587
# Epoch 49/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 3s - loss: -0.9692counter 55
# Inside On epoch end
# counter 1
# sl slice(0, 5749, None)
# sl slice(0, 3000, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.9638, 0.7835]
# 2/2 [==============================] - 12s 6s/step - loss: -0.9667
# Epoch 50/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 3s - loss: -0.9647counter 56
# Inside On epoch end
# counter 1
# sl slice(0, 5749, None)
# sl slice(0, 3000, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.9748, 0.7876]
# 2/2 [==============================] - 11s 6s/step - loss: -0.9656
# Epoch 51/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 3s - loss: -0.9751counter 57
# Inside On epoch end
# counter 1
# sl slice(0, 3000, None)
# sl slice(0, 5749, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.9752, 0.8123]
# 2/2 [==============================] - 12s 6s/step - loss: -0.9760
# Epoch 52/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 3s - loss: -0.9735counter 58
# Inside On epoch end
# counter 1
# sl slice(0, 5749, None)
# sl slice(0, 3000, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.9767, 0.8034]
# 2/2 [==============================] - 11s 6s/step - loss: -0.9752
# Epoch 53/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 3s - loss: -0.9744counter 59
# Inside On epoch end
# counter 1
# sl slice(0, 5749, None)
# sl slice(0, 3000, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.9817, 0.8062]
# 2/2 [==============================] - 12s 6s/step - loss: -0.9780
# Epoch 54/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 3s - loss: -0.9814counter 60
# Inside On epoch end
# counter 1
# sl slice(0, 5749, None)
# sl slice(0, 3000, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.9804, 0.8037]
# 2/2 [==============================] - 12s 6s/step - loss: -0.9814
# Epoch 55/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 3s - loss: -0.9820counter 61
# Inside On epoch end
# counter 1
# sl slice(0, 5749, None)
# sl slice(0, 3000, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.985, 0.8084]
# 2/2 [==============================] - 11s 6s/step - loss: -0.9809
# Epoch 56/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 3s - loss: -0.9870counter 62
# Inside On epoch end
# counter 1
# sl slice(0, 5749, None)
# sl slice(0, 3000, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.9857, 0.8067]
# 2/2 [==============================] - 11s 6s/step - loss: -0.9853
# Epoch 57/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 3s - loss: -0.9850counter 63
# Inside On epoch end
# counter 1
# sl slice(0, 5749, None)
# sl slice(0, 3000, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.9876, 0.8106]
# 2/2 [==============================] - 11s 6s/step - loss: -0.9858
# Epoch 58/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 3s - loss: -0.9881counter 64
# Inside On epoch end
# counter 1
# sl slice(0, 5749, None)
# sl slice(0, 3000, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.9883, 0.8038]
# 2/2 [==============================] - 11s 6s/step - loss: -0.9879
# Epoch 59/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 3s - loss: -0.9897counter 65
# Inside On epoch end
# counter 1
# sl slice(0, 5749, None)
# sl slice(0, 3000, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.9892, 0.8014]
# 2/2 [==============================] - 12s 6s/step - loss: -0.9884
# Epoch 60/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 3s - loss: -0.9896counter 66
# Inside On epoch end
# counter 1
# sl slice(0, 3000, None)
# sl slice(0, 5749, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.991, 0.8038]
# 2/2 [==============================] - 12s 6s/step - loss: -0.9896
# Epoch 61/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 3s - loss: -0.9902counter 67
# Inside On epoch end
# counter 1
# sl slice(0, 3000, None)
# sl slice(0, 5749, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.991, 0.8093]
# 2/2 [==============================] - 11s 5s/step - loss: -0.9909
# Epoch 62/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 3s - loss: -0.9905counter 68
# Inside On epoch end
# counter 1
# sl slice(0, 5749, None)
# sl slice(0, 3000, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.9922, 0.8073]
# 2/2 [==============================] - 11s 6s/step - loss: -0.9913
# Epoch 63/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 3s - loss: -0.9926counter 69
# Inside On epoch end
# counter 1
# sl slice(0, 5749, None)
# sl slice(0, 3000, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.9926, 0.8035]
# 2/2 [==============================] - 11s 5s/step - loss: -0.9921
# Epoch 64/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 3s - loss: -0.9915counter 70
# Inside On epoch end
# counter 1
# sl slice(0, 5749, None)
# sl slice(0, 3000, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.9935, 0.8054]
# 2/2 [==============================] - 11s 6s/step - loss: -0.9928
# Prediction(best valid epoch)
# counter 1
# sl slice(0, 5749, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.9398, 0.8143]
# RunID: 1
# inside convo:
# (?, 60, 300)
# (?, 60, 300)
# (?, 60, 1800)
# (?, 60, 1800)
# inside max
# (?, 1, 1800)
# (?, 1, 1800)
# inside flat
# (?, 1800)
# (?, 1800)
# (?, 1800)
# (?, 3600)
# inside dense
# (?, 1800)
# kd
# (?, 6)
# Training
# Epoch 1/64
# counter 1
# sl slice(0, 3000, None)
# sl slice(3000, 6000, None)
# counter 2
# sl slice(0, 3000, None)
# sl slice(3000, 6000, None)
# counter 3
# 1/2 [==============>...............] - ETA: 6s - loss: -0.2191sl slice(0, 3000, None)
# sl slice(3000, 6000, None)
# counter 4
# Inside On epoch end
# counter 1
# sl slice(0, 3000, None)
# sl slice(3000, 6000, None)
# counter 5
# sl slice(0, 5749, None)
# sl slice(0, 3000, None)
# sl slice(3000, 6000, None)
# counter 6
# sl slice(0, 3000, None)
# sl slice(3000, 6000, None)
# counter 7
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.6241, 0.6776]
# 2/2 [==============================] - 16s 8s/step - loss: -0.3290
# Epoch 2/64
# sl slice(0, 3000, None)
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 3s - loss: -0.6232counter 8
# Inside On epoch end
# counter 1
# sl slice(0, 5749, None)
# sl slice(0, 3000, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.5972, 0.5849]
# 2/2 [==============================] - 10s 5s/step - loss: -0.6101
# Epoch 3/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 3s - loss: -0.6060counter 9
# Inside On epoch end
# counter 1
# sl slice(0, 3000, None)
# sl slice(0, 5749, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.6473, 0.6707]
# 2/2 [==============================] - 11s 5s/step - loss: -0.6091
# Epoch 4/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 3s - loss: -0.6517counter 10
# Inside On epoch end
# counter 1
# sl slice(0, 3000, None)
# sl slice(0, 5749, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.6534, 0.699]
# 2/2 [==============================] - 11s 6s/step - loss: -0.6501
# Epoch 5/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 3s - loss: -0.6492counter 11
# Inside On epoch end
# counter 1
# sl slice(0, 5749, None)
# sl slice(0, 3000, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.6665, 0.7042]
# 2/2 [==============================] - 12s 6s/step - loss: -0.6542
# Epoch 6/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 3s - loss: -0.6660counter 12
# Inside On epoch end
# counter 1
# sl slice(0, 5749, None)
# sl slice(0, 3000, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.685, 0.6997]
# 2/2 [==============================] - 11s 6s/step - loss: -0.6703
# Epoch 7/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 3s - loss: -0.6920counter 13
# Inside On epoch end
# counter 1
# sl slice(0, 5749, None)
# sl slice(0, 3000, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.6901, 0.6861]
# 2/2 [==============================] - 12s 6s/step - loss: -0.6839
# Epoch 8/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 3s - loss: -0.6981counter 14
# Inside On epoch end
# counter 1
# sl slice(0, 3000, None)
# sl slice(0, 5749, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.71, 0.7066]
# 2/2 [==============================] - 13s 6s/step - loss: -0.6934
# Epoch 9/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 3s - loss: -0.7124counter 15
# Inside On epoch end
# counter 1
# sl slice(0, 5749, None)
# sl slice(0, 3000, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.7195, 0.7259]
# 2/2 [==============================] - 12s 6s/step - loss: -0.7113
# Epoch 10/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 3s - loss: -0.7190counter 16
# Inside On epoch end
# counter 1
# sl slice(0, 5749, None)
# sl slice(0, 3000, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.7357, 0.7301]
# 2/2 [==============================] - 12s 6s/step - loss: -0.7226
# Epoch 11/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 3s - loss: -0.7295counter 17
# Inside On epoch end
# counter 1
# sl slice(0, 5749, None)
# sl slice(0, 3000, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.745, 0.7298]
# 2/2 [==============================] - 10s 5s/step - loss: -0.7375
# Epoch 12/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 3s - loss: -0.7423counter 18
# Inside On epoch end
# counter 1
# sl slice(0, 3000, None)
# sl slice(0, 5749, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.7592, 0.7483]
# 2/2 [==============================] - 13s 6s/step - loss: -0.7476
# Epoch 13/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 3s - loss: -0.7556counter 19
# Inside On epoch end
# counter 1
# sl slice(0, 5749, None)
# sl slice(0, 3000, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.7694, 0.7625]
# 2/2 [==============================] - 11s 6s/step - loss: -0.7603
# Epoch 14/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 3s - loss: -0.7643counter 20
# Inside On epoch end
# counter 1
# sl slice(0, 5749, None)
# sl slice(0, 3000, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.781, 0.7655]
# 2/2 [==============================] - 12s 6s/step - loss: -0.7738
# Epoch 15/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 3s - loss: -0.7812counter 21
# Inside On epoch end
# counter 1
# sl slice(0, 5749, None)
# sl slice(0, 3000, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.7929, 0.7866]
# 2/2 [==============================] - 11s 6s/step - loss: -0.7865
# Epoch 16/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 3s - loss: -0.7962counter 22
# Inside On epoch end
# counter 1
# sl slice(0, 5749, None)
# sl slice(0, 3000, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.7961, 0.7779]
# 2/2 [==============================] - 11s 6s/step - loss: -0.7972
# Epoch 17/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 8s - loss: -0.7872counter 23
# Inside On epoch end
# counter 1
# sl slice(0, 5749, None)
# sl slice(0, 3000, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.8028, 0.7917]
# 2/2 [==============================] - 18s 9s/step - loss: -0.8027
# Epoch 18/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 3s - loss: -0.8001counter 24
# Inside On epoch end
# counter 1
# sl slice(0, 5749, None)
# counter 1
# sl slice(0, 1500, None)
# sl slice(0, 3000, None)
# [Train, Valid]=[0.8181, 0.7944]
# 2/2 [==============================] - 12s 6s/step - loss: -0.8082
# Epoch 19/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 3s - loss: -0.8203counter 25
# Inside On epoch end
# counter 1
# sl slice(0, 5749, None)
# sl slice(0, 3000, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.8279, 0.8016]
# 2/2 [==============================] - 12s 6s/step - loss: -0.8174
# Epoch 20/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 3s - loss: -0.8258counter 26
# Inside On epoch end
# counter 1
# sl slice(0, 5749, None)
# sl slice(0, 3000, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.8349, 0.8015]
# 2/2 [==============================] - 11s 5s/step - loss: -0.8246
# Epoch 21/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 3s - loss: -0.8309counter 27
# Inside On epoch end
# counter 1
# sl slice(0, 3000, None)
# sl slice(0, 5749, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.8421, 0.8035]
# 2/2 [==============================] - 12s 6s/step - loss: -0.8314
# Epoch 22/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 3s - loss: -0.8455counter 28
# Inside On epoch end
# counter 1
# sl slice(0, 5749, None)
# sl slice(0, 3000, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.8507, 0.8062]
# 2/2 [==============================] - 11s 6s/step - loss: -0.8423
# Epoch 23/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 3s - loss: -0.8519counter 29
# Inside On epoch end
# counter 1
# sl slice(0, 5749, None)
# sl slice(0, 3000, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.8587, 0.8071]
# 2/2 [==============================] - 12s 6s/step - loss: -0.8511
# Epoch 24/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 3s - loss: -0.8622counter 30
# Inside On epoch end
# counter 1
# sl slice(0, 5749, None)
# sl slice(0, 3000, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.8655, 0.8108]
# 2/2 [==============================] - 11s 6s/step - loss: -0.8598
# Epoch 25/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 3s - loss: -0.8594counter 31
# Inside On epoch end
# counter 1
# sl slice(0, 5749, None)
# sl slice(0, 3000, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.8734, 0.8096]
# 2/2 [==============================] - 10s 5s/step - loss: -0.8681
# Epoch 26/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 3s - loss: -0.8758counter 32
# Inside On epoch end
# counter 1
# sl slice(0, 5749, None)
# sl slice(0, 3000, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.8828, 0.8164]
# 2/2 [==============================] - 12s 6s/step - loss: -0.8756
# Epoch 27/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 3s - loss: -0.8802counter 33
# Inside On epoch end
# counter 1
# sl slice(0, 5749, None)
# sl slice(0, 3000, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.8886, 0.816]
# 2/2 [==============================] - 11s 6s/step - loss: -0.8829
# Epoch 28/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 3s - loss: -0.8890counter 34
# Inside On epoch end
# counter 1
# sl slice(0, 3000, None)
# sl slice(0, 5749, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.8983, 0.814]
# 2/2 [==============================] - 12s 6s/step - loss: -0.8907
# Epoch 29/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 3s - loss: -0.9009counter 35
# Inside On epoch end
# counter 1
# sl slice(0, 5749, None)
# sl slice(0, 3000, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.9052, 0.8155]
# 2/2 [==============================] - 11s 5s/step - loss: -0.8994
# Epoch 30/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 3s - loss: -0.9068counter 36
# Inside On epoch end
# counter 1
# sl slice(0, 5749, None)
# sl slice(0, 3000, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.9124, 0.816]
# 2/2 [==============================] - 11s 5s/step - loss: -0.9071
# Epoch 31/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 3s - loss: -0.9052counter 37
# Inside On epoch end
# counter 1
# sl slice(0, 5749, None)
# sl slice(0, 3000, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.9168, 0.8121]
# 2/2 [==============================] - 11s 5s/step - loss: -0.9120
# Epoch 32/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 3s - loss: -0.9175counter 38
# Inside On epoch end
# counter 1
# sl slice(0, 5749, None)
# sl slice(0, 3000, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.9275, 0.8153]
# 2/2 [==============================] - 11s 5s/step - loss: -0.9203
# Epoch 33/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 3s - loss: -0.9229counter 39
# Inside On epoch end
# counter 1
# sl slice(0, 5749, None)
# sl slice(0, 3000, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.93, 0.8067]
# 2/2 [==============================] - 11s 5s/step - loss: -0.9275
# Epoch 34/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 3s - loss: -0.9256counter 40
# Inside On epoch end
# counter 1
# sl slice(0, 5749, None)
# sl slice(0, 3000, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.9415, 0.813]
# 2/2 [==============================] - 11s 5s/step - loss: -0.9320
# Epoch 35/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 3s - loss: -0.9445counter 41
# Inside On epoch end
# counter 1
# sl slice(0, 5749, None)
# sl slice(0, 3000, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.9399, 0.8095]
# 2/2 [==============================] - 11s 6s/step - loss: -0.9414
# Epoch 36/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 3s - loss: -0.9377counter 42
# Inside On epoch end
# counter 1
# sl slice(0, 5749, None)
# sl slice(0, 3000, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.9528, 0.8154]
# 2/2 [==============================] - 10s 5s/step - loss: -0.9431
# Epoch 37/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 3s - loss: -0.9483counter 43
# Inside On epoch end
# counter 1
# sl slice(0, 5749, None)
# sl slice(0, 3000, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.9473, 0.8055]
# 2/2 [==============================] - 10s 5s/step - loss: -0.9489
# Epoch 38/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 2s - loss: -0.9459counter 44
# Inside On epoch end
# counter 1
# sl slice(0, 5749, None)
# sl slice(0, 3000, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.956, 0.8068]
# 2/2 [==============================] - 10s 5s/step - loss: -0.9529
# Epoch 39/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 3s - loss: -0.9546counter 45
# Inside On epoch end
# counter 1
# sl slice(0, 5749, None)
# sl slice(0, 3000, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.9652, 0.8182]
# 2/2 [==============================] - 12s 6s/step - loss: -0.9565
# Epoch 40/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 3s - loss: -0.9641counter 46
# Inside On epoch end
# counter 1
# sl slice(0, 5749, None)
# sl slice(0, 3000, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.9647, 0.7969]
# 2/2 [==============================] - 11s 5s/step - loss: -0.9621
# Epoch 41/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 3s - loss: -0.9647counter 47
# Inside On epoch end
# counter 1
# sl slice(0, 3000, None)
# sl slice(0, 5749, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.9649, 0.8104]
# 2/2 [==============================] - 11s 5s/step - loss: -0.9672
# Epoch 42/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 3s - loss: -0.9620counter 48
# Inside On epoch end
# counter 1
# sl slice(0, 5749, None)
# sl slice(0, 3000, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.9737, 0.8036]
# 2/2 [==============================] - 11s 5s/step - loss: -0.9678
# Epoch 43/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 3s - loss: -0.9724counter 49
# Inside On epoch end
# counter 1
# sl slice(0, 5749, None)
# sl slice(0, 3000, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.9757, 0.8188]
# 2/2 [==============================] - 11s 6s/step - loss: -0.9723
# Epoch 44/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 3s - loss: -0.9747counter 50
# Inside On epoch end
# counter 1
# sl slice(0, 5749, None)
# sl slice(0, 3000, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.9778, 0.7976]
# 2/2 [==============================] - 11s 6s/step - loss: -0.9760
# Epoch 45/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 3s - loss: -0.9768counter 51
# Inside On epoch end
# counter 1
# sl slice(0, 5749, None)
# sl slice(0, 3000, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.9811, 0.8174]
# 2/2 [==============================] - 11s 6s/step - loss: -0.9798
# Epoch 46/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 3s - loss: -0.9834counter 52
# Inside On epoch end
# counter 1
# sl slice(0, 5749, None)
# sl slice(0, 3000, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.9848, 0.8059]
# 2/2 [==============================] - 11s 6s/step - loss: -0.9818
# Epoch 47/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 3s - loss: -0.9833counter 53
# Inside On epoch end
# counter 1
# sl slice(0, 5749, None)
# sl slice(0, 3000, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.9858, 0.8156]
# 2/2 [==============================] - 11s 6s/step - loss: -0.9846
# Epoch 48/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 3s - loss: -0.9867counter 54
# Inside On epoch end
# counter 1
# sl slice(0, 5749, None)
# sl slice(0, 3000, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.9872, 0.8037]
# 2/2 [==============================] - 11s 5s/step - loss: -0.9863
# Epoch 49/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 3s - loss: -0.9889counter 55
# Inside On epoch end
# counter 1
# sl slice(0, 5749, None)
# sl slice(0, 3000, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.9884, 0.8138]
# 2/2 [==============================] - 11s 5s/step - loss: -0.9881
# Epoch 50/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 3s - loss: -0.9892counter 56
# Inside On epoch end
# counter 1
# sl slice(0, 5749, None)
# sl slice(0, 3000, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.9905, 0.8048]
# 2/2 [==============================] - 11s 5s/step - loss: -0.9885
# Epoch 51/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 3s - loss: -0.9917counter 57
# Inside On epoch end
# counter 1
# sl slice(0, 5749, None)
# sl slice(0, 3000, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.9913, 0.815]
# 2/2 [==============================] - 11s 6s/step - loss: -0.9908
# Epoch 52/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 3s - loss: -0.9904counter 58
# Inside On epoch end
# counter 1
# sl slice(0, 5749, None)
# sl slice(0, 3000, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.9917, 0.8037]
# 2/2 [==============================] - 11s 5s/step - loss: -0.9916
# Epoch 53/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 3s - loss: -0.9910counter 59
# Inside On epoch end
# counter 1
# sl slice(0, 5749, None)
# sl slice(0, 3000, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.9919, 0.8143]
# 2/2 [==============================] - 11s 5s/step - loss: -0.9923
# Epoch 54/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 3s - loss: -0.9909counter 60
# Inside On epoch end
# counter 1
# sl slice(0, 5749, None)
# sl slice(0, 3000, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.9932, 0.8031]
# 2/2 [==============================] - 11s 6s/step - loss: -0.9925
# Epoch 55/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 3s - loss: -0.9923counter 61
# Inside On epoch end
# counter 1
# sl slice(0, 5749, None)
# sl slice(0, 3000, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.9936, 0.8129]
# 2/2 [==============================] - 11s 5s/step - loss: -0.9935
# Epoch 56/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 3s - loss: -0.9921counter 62
# Inside On epoch end
# counter 1
# sl slice(0, 5749, None)
# sl slice(0, 3000, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.9941, 0.804]
# 2/2 [==============================] - 11s 5s/step - loss: -0.9941
# Epoch 57/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 3s - loss: -0.9930counter 63
# Inside On epoch end
# counter 1
# sl slice(0, 5749, None)
# sl slice(0, 3000, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.9951, 0.8117]
# 2/2 [==============================] - 10s 5s/step - loss: -0.9940
# Epoch 58/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 3s - loss: -0.9940counter 64
# Inside On epoch end
# counter 1
# sl slice(0, 5749, None)
# sl slice(0, 3000, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.9954, 0.8087]
# 2/2 [==============================] - 11s 5s/step - loss: -0.9952
# Epoch 59/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 3s - loss: -0.9948counter 65
# Inside On epoch end
# counter 1
# sl slice(0, 3000, None)
# sl slice(0, 5749, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.9959, 0.8099]
# 2/2 [==============================] - 11s 6s/step - loss: -0.9955
# Epoch 60/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 3s - loss: -0.9949counter 66
# Inside On epoch end
# counter 1
# sl slice(0, 3000, None)
# sl slice(0, 5749, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.9956, 0.8093]
# 2/2 [==============================] - 11s 6s/step - loss: -0.9958
# Epoch 61/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 3s - loss: -0.9946counter 67
# Inside On epoch end
# counter 1
# sl slice(0, 3000, None)
# sl slice(0, 5749, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.9963, 0.8081]
# 2/2 [==============================] - 11s 5s/step - loss: -0.9959
# Epoch 62/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 3s - loss: -0.9972counter 68
# Inside On epoch end
# counter 1
# sl slice(0, 5749, None)
# sl slice(0, 3000, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.9959, 0.8108]
# 2/2 [==============================] - 11s 5s/step - loss: -0.9959
# Epoch 63/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 3s - loss: -0.9967counter 69
# Inside On epoch end
# counter 1
# sl slice(0, 5749, None)
# sl slice(0, 3000, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.9966, 0.8075]
# 2/2 [==============================] - 11s 6s/step - loss: -0.9962
# Epoch 64/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 3s - loss: -0.9974counter 70
# Inside On epoch end
# counter 1
# sl slice(0, 5749, None)
# sl slice(0, 3000, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.9968, 0.8105]
# 2/2 [==============================] - 11s 5s/step - loss: -0.9966
# Prediction(best valid epoch)
# counter 1
# sl slice(0, 5749, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.9757, 0.8188]
# RunID: 2
# inside convo:
# (?, 60, 300)
# (?, 60, 300)
# (?, 60, 1800)
# (?, 60, 1800)
# inside max
# (?, 1, 1800)
# (?, 1, 1800)
# inside flat
# (?, 1800)
# (?, 1800)
# (?, 1800)
# (?, 3600)
# inside dense
# (?, 1800)
# kd
# (?, 6)
# Training
# Epoch 1/64
# counter 1
# sl slice(0, 3000, None)
# sl slice(3000, 6000, None)
# counter 2
# sl slice(0, 3000, None)
# sl slice(3000, 6000, None)
# counter 3
# sl slice(0, 3000, None)
# sl slice(3000, 6000, None)
# counter 4
# 1/2 [==============>...............] - ETA: 5s - loss: -0.1360Inside On epoch end
# counter 1
# sl slice(0, 3000, None)
# sl slice(3000, 6000, None)
# counter 5
# sl slice(0, 5749, None)
# sl slice(0, 3000, None)
# sl slice(3000, 6000, None)
# counter 6
# counter 1
# sl slice(0, 1500, None)
# sl slice(0, 3000, None)
# sl slice(3000, 6000, None)
# counter 7
# [Train, Valid]=[0.5553, 0.5493]
# 2/2 [==============================] - 14s 7s/step - loss: -0.2816
# Epoch 2/64
# sl slice(0, 3000, None)
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 3s - loss: -0.5522counter 8
# Inside On epoch end
# counter 1
# sl slice(0, 5749, None)
# sl slice(0, 3000, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.6171, 0.6708]
# 2/2 [==============================] - 12s 6s/step - loss: -0.5785
# Epoch 3/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 3s - loss: -0.6153counter 9
# Inside On epoch end
# counter 1
# sl slice(0, 5749, None)
# sl slice(0, 3000, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.6324, 0.685]
# 2/2 [==============================] - 12s 6s/step - loss: -0.6162
# Epoch 4/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 3s - loss: -0.6190counter 10
# Inside On epoch end
# counter 1
# sl slice(0, 5749, None)
# sl slice(0, 3000, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.6533, 0.7085]
# 2/2 [==============================] - 12s 6s/step - loss: -0.6421
# Epoch 5/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 3s - loss: -0.6548counter 11
# Inside On epoch end
# counter 1
# sl slice(0, 5749, None)
# sl slice(0, 3000, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.6769, 0.715]
# 2/2 [==============================] - 12s 6s/step - loss: -0.6577
# Epoch 6/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 3s - loss: -0.6696counter 12
# Inside On epoch end
# counter 1
# sl slice(0, 5749, None)
# sl slice(0, 3000, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.6895, 0.7173]
# 2/2 [==============================] - 12s 6s/step - loss: -0.6803
# Epoch 7/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 3s - loss: -0.6883counter 13
# Inside On epoch end
# counter 1
# sl slice(0, 5749, None)
# sl slice(0, 3000, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.698, 0.7194]
# 2/2 [==============================] - 12s 6s/step - loss: -0.6911
# Epoch 8/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 3s - loss: -0.6971counter 14
# Inside On epoch end
# counter 1
# sl slice(0, 5749, None)
# sl slice(0, 3000, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.7047, 0.7274]
# 2/2 [==============================] - 12s 6s/step - loss: -0.6989
# Epoch 9/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 3s - loss: -0.7037counter 15
# Inside On epoch end
# counter 1
# sl slice(0, 5749, None)
# sl slice(0, 3000, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.716, 0.7305]
# 2/2 [==============================] - 13s 6s/step - loss: -0.7068
# Epoch 10/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 4s - loss: -0.7244counter 16
# Inside On epoch end
# counter 1
# sl slice(0, 5749, None)
# sl slice(0, 3000, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.7286, 0.7335]
# 2/2 [==============================] - 13s 6s/step - loss: -0.7186
# Epoch 11/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 3s - loss: -0.7392counter 17
# Inside On epoch end
# counter 1
# sl slice(0, 5749, None)
# sl slice(0, 3000, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.7438, 0.7429]
# 2/2 [==============================] - 13s 6s/step - loss: -0.7314
# Epoch 12/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 3s - loss: -0.7391counter 18
# Inside On epoch end
# counter 1
# sl slice(0, 3000, None)
# sl slice(0, 5749, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.759, 0.7559]
# 2/2 [==============================] - 13s 6s/step - loss: -0.7459
# Epoch 13/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 3s - loss: -0.7525counter 19
# Inside On epoch end
# counter 1
# sl slice(0, 5749, None)
# sl slice(0, 3000, None)
# counter 1
# ...
# Inside On epoch end
# counter 1
# sl slice(0, 5749, None)
# sl slice(0, 3000, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.8115, 0.7804]
# 2/2 [==============================] - 13s 6s/step - loss: -0.8032
# Epoch 17/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 3s - loss: -0.8179counter 23
# Inside On epoch end
# counter 1
# sl slice(0, 3000, None)
# sl slice(0, 5749, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.8297, 0.7824]
# 2/2 [==============================] - 12s 6s/step - loss: -0.8146
# Epoch 18/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 3s - loss: -0.8271counter 24
# Inside On epoch end
# counter 1
# sl slice(0, 3000, None)
# sl slice(0, 5749, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.815, 0.7749]
# 2/2 [==============================] - 12s 6s/step - loss: -0.8230
# Epoch 19/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 3s - loss: -0.8207counter 25
# Inside On epoch end
# counter 1
# sl slice(0, 3000, None)
# sl slice(0, 5749, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.8326, 0.7796]
# 2/2 [==============================] - 12s 6s/step - loss: -0.8282
# Epoch 20/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 3s - loss: -0.8289counter 26
# Inside On epoch end
# counter 1
# sl slice(0, 3000, None)
# sl slice(0, 5749, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.8565, 0.7925]
# 2/2 [==============================] - 12s 6s/step - loss: -0.8401
# Epoch 21/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 3s - loss: -0.8554counter 27
# Inside On epoch end
# counter 1
# sl slice(0, 3000, None)
# sl slice(0, 5749, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.8693, 0.7987]
# 2/2 [==============================] - 13s 6s/step - loss: -0.8474
# Epoch 22/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 3s - loss: -0.8669counter 28
# Inside On epoch end
# counter 1
# sl slice(0, 3000, None)
# sl slice(0, 5749, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.872, 0.7959]
# 2/2 [==============================] - 13s 6s/step - loss: -0.8664
# Epoch 23/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 3s - loss: -0.8730counter 29
# Inside On epoch end
# counter 1
# sl slice(0, 3000, None)
# sl slice(0, 5749, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.8733, 0.7836]
# 2/2 [==============================] - 12s 6s/step - loss: -0.8756
# Epoch 24/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 3s - loss: -0.8751counter 30
# Inside On epoch end
# counter 1
# sl slice(0, 3000, None)
# sl slice(0, 5749, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.891, 0.7973]
# 2/2 [==============================] - 12s 6s/step - loss: -0.8808
# Epoch 25/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 3s - loss: -0.8922counter 31
# Inside On epoch end
# counter 1
# sl slice(0, 3000, None)
# sl slice(0, 5749, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.9016, 0.8019]
# 2/2 [==============================] - 13s 6s/step - loss: -0.8914
# Epoch 26/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 3s - loss: -0.8992counter 32
# Inside On epoch end
# counter 1
# sl slice(0, 3000, None)
# sl slice(0, 5749, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.911, 0.7947]
# 2/2 [==============================] - 12s 6s/step - loss: -0.9014
# Epoch 27/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 3s - loss: -0.9108counter 33
# Inside On epoch end
# counter 1
# sl slice(0, 3000, None)
# sl slice(0, 5749, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.9108, 0.7897]
# 2/2 [==============================] - 12s 6s/step - loss: -0.9093
# Epoch 28/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 3s - loss: -0.9102counter 34
# Inside On epoch end
# counter 1
# sl slice(0, 3000, None)
# sl slice(0, 5749, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.9206, 0.7787]
# 2/2 [==============================] - 12s 6s/step - loss: -0.9130
# Epoch 29/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 3s - loss: -0.9238counter 35
# Inside On epoch end
# counter 1
# sl slice(0, 3000, None)
# sl slice(0, 5749, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.9227, 0.8016]
# 2/2 [==============================] - 12s 6s/step - loss: -0.9221
# Epoch 30/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 3s - loss: -0.9237counter 36
# Inside On epoch end
# counter 1
# sl slice(0, 3000, None)
# sl slice(0, 5749, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.9276, 0.7791]
# 2/2 [==============================] - 12s 6s/step - loss: -0.9260
# Epoch 31/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 3s - loss: -0.9311counter 37
# Inside On epoch end
# counter 1
# sl slice(0, 3000, None)
# sl slice(0, 5749, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.9354, 0.7978]
# 2/2 [==============================] - 13s 6s/step - loss: -0.9297
# Epoch 32/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 3s - loss: -0.9368counter 38
# Inside On epoch end
# counter 1
# sl slice(0, 3000, None)
# sl slice(0, 5749, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.9366, 0.7856]
# 2/2 [==============================] - 12s 6s/step - loss: -0.9352
# Epoch 33/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 3s - loss: -0.9378counter 39
# Inside On epoch end
# counter 1
# sl slice(0, 3000, None)
# sl slice(0, 5749, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.9399, 0.7937]
# 2/2 [==============================] - 12s 6s/step - loss: -0.9393
# Epoch 34/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 4s - loss: -0.9410counter 40
# Inside On epoch end
# counter 1
# sl slice(0, 3000, None)
# sl slice(0, 5749, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.9459, 0.7851]
# 2/2 [==============================] - 12s 6s/step - loss: -0.9405
# Epoch 35/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 3s - loss: -0.9441counter 41
# Inside On epoch end
# counter 1
# sl slice(0, 3000, None)
# sl slice(0, 5749, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.9488, 0.7957]
# 2/2 [==============================] - 12s 6s/step - loss: -0.9472
# Epoch 36/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 3s - loss: -0.9490counter 42
# Inside On epoch end
# counter 1
# sl slice(0, 3000, None)
# sl slice(0, 5749, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.9516, 0.7759]
# 2/2 [==============================] - 12s 6s/step - loss: -0.9501
# Epoch 37/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 3s - loss: -0.9527counter 43
# Inside On epoch end
# counter 1
# sl slice(0, 3000, None)
# sl slice(0, 5749, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.9545, 0.797]
# 2/2 [==============================] - 12s 6s/step - loss: -0.9528
# Epoch 38/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 3s - loss: -0.9580counter 44
# Inside On epoch end
# counter 1
# sl slice(0, 3000, None)
# sl slice(0, 5749, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.956, 0.7874]
# 2/2 [==============================] - 12s 6s/step - loss: -0.9551
# Epoch 39/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 4s - loss: -0.9577counter 45
# Inside On epoch end
# counter 1
# sl slice(0, 3000, None)
# sl slice(0, 5749, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.9587, 0.7919]
# 2/2 [==============================] - 13s 6s/step - loss: -0.9569
# Epoch 40/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 3s - loss: -0.9574counter 46
# Inside On epoch end
# counter 1
# sl slice(0, 3000, None)
# sl slice(0, 5749, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.9595, 0.7821]
# 2/2 [==============================] - 12s 6s/step - loss: -0.9588
# Epoch 41/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 3s - loss: -0.9604counter 47
# Inside On epoch end
# counter 1
# sl slice(0, 3000, None)
# sl slice(0, 5749, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.96, 0.7872]
# 2/2 [==============================] - 12s 6s/step - loss: -0.9588
# Epoch 42/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 4s - loss: -0.9608counter 48
# Inside On epoch end
# counter 1
# sl slice(0, 3000, None)
# sl slice(0, 5749, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.963, 0.793]
# 2/2 [==============================] - 13s 6s/step - loss: -0.9615
# Epoch 43/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 4s - loss: -0.9633counter 49
# Inside On epoch end
# counter 1
# sl slice(0, 3000, None)
# sl slice(0, 5749, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.9574, 0.7848]
# 2/2 [==============================] - 12s 6s/step - loss: -0.9612
# Epoch 44/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 4s - loss: -0.9599counter 50
# Inside On epoch end
# counter 1
# sl slice(0, 3000, None)
# sl slice(0, 5749, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.9638, 0.7971]
# 2/2 [==============================] - 13s 6s/step - loss: -0.9587
# Epoch 45/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 3s - loss: -0.9630counter 51
# Inside On epoch end
# counter 1
# sl slice(0, 3000, None)
# sl slice(0, 5749, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.9634, 0.7824]
# 2/2 [==============================] - 12s 6s/step - loss: -0.9646
# Epoch 46/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 3s - loss: -0.9629counter 52
# Inside On epoch end
# counter 1
# sl slice(0, 3000, None)
# sl slice(0, 5749, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.9646, 0.7846]
# 2/2 [==============================] - 12s 6s/step - loss: -0.9626
# Epoch 47/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 3s - loss: -0.9655counter 53
# Inside On epoch end
# counter 1
# sl slice(0, 3000, None)
# sl slice(0, 5749, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.9667, 0.797]
# 2/2 [==============================] - 12s 6s/step - loss: -0.9655
# Epoch 48/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 4s - loss: -0.9647counter 54
# Inside On epoch end
# counter 1
# sl slice(0, 3000, None)
# sl slice(0, 5749, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.9636, 0.7853]
# 2/2 [==============================] - 13s 6s/step - loss: -0.9658
# Epoch 49/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 3s - loss: -0.9629counter 55
# Inside On epoch end
# counter 1
# sl slice(0, 3000, None)
# sl slice(0, 5749, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.9686, 0.7952]
# 2/2 [==============================] - 12s 6s/step - loss: -0.9651
# Epoch 50/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 4s - loss: -0.9668counter 56
# Inside On epoch end
# counter 1
# sl slice(0, 3000, None)
# sl slice(0, 5749, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.9697, 0.7921]
# 2/2 [==============================] - 13s 7s/step - loss: -0.9686
# Epoch 51/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 3s - loss: -0.9672counter 57
# Inside On epoch end
# counter 1
# sl slice(0, 3000, None)
# sl slice(0, 5749, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.9694, 0.7878]
# 2/2 [==============================] - 13s 6s/step - loss: -0.9694
# Epoch 52/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 3s - loss: -0.9707counter 58
# Inside On epoch end
# counter 1
# sl slice(0, 3000, None)
# sl slice(0, 5749, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.9703, 0.7964]
# 2/2 [==============================] - 12s 6s/step - loss: -0.9698
# Epoch 53/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 3s - loss: -0.9687counter 59
# Inside On epoch end
# counter 1
# sl slice(0, 3000, None)
# sl slice(0, 5749, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.9704, 0.7908]
# 2/2 [==============================] - 12s 6s/step - loss: -0.9707
# Epoch 54/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 3s - loss: -0.9701counter 60
# Inside On epoch end
# counter 1
# sl slice(0, 3000, None)
# sl slice(0, 5749, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.9672, 0.7909]
# 2/2 [==============================] - 12s 6s/step - loss: -0.9698
# Epoch 55/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 3s - loss: -0.9656counter 61
# Inside On epoch end
# counter 1
# sl slice(0, 3000, None)
# sl slice(0, 5749, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.9627, 0.7911]
# 2/2 [==============================] - 12s 6s/step - loss: -0.9658
# Epoch 56/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 4s - loss: -0.9626counter 62
# Inside On epoch end
# counter 1
# sl slice(0, 5749, None)
# sl slice(0, 3000, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.9638, 0.7864]
# 2/2 [==============================] - 12s 6s/step - loss: -0.9621
# Epoch 57/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 4s - loss: -0.9622counter 63
# Inside On epoch end
# counter 1
# sl slice(0, 5749, None)
# sl slice(0, 3000, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.9718, 0.7953]
# 2/2 [==============================] - 12s 6s/step - loss: -0.9659
# Epoch 58/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 3s - loss: -0.9739counter 64
# Inside On epoch end
# counter 1
# sl slice(0, 5749, None)
# sl slice(0, 3000, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.9681, 0.7921]
# 2/2 [==============================] - 12s 6s/step - loss: -0.9710
# Epoch 59/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 3s - loss: -0.9672counter 65
# Inside On epoch end
# counter 1
# sl slice(0, 5749, None)
# sl slice(0, 3000, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.9669, 0.7814]
# 2/2 [==============================] - 12s 6s/step - loss: -0.9677
# Epoch 60/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 3s - loss: -0.9653counter 66
# Inside On epoch end
# counter 1
# sl slice(0, 5749, None)
# sl slice(0, 3000, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.9725, 0.7944]
# 2/2 [==============================] - 12s 6s/step - loss: -0.9680
# Epoch 61/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 4s - loss: -0.9688counter 67
# Inside On epoch end
# counter 1
# sl slice(0, 5749, None)
# sl slice(0, 3000, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.9703, 0.7973]
# 2/2 [==============================] - 13s 6s/step - loss: -0.9720
# Epoch 62/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 3s - loss: -0.9732counter 68
# Inside On epoch end
# counter 1
# sl slice(0, 5749, None)
# sl slice(0, 3000, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.9685, 0.7857]
# 2/2 [==============================] - 12s 6s/step - loss: -0.9700
# Epoch 63/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 3s - loss: -0.9703counter 69
# Inside On epoch end
# counter 1
# sl slice(0, 5749, None)
# sl slice(0, 3000, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.9729, 0.7967]
# 2/2 [==============================] - 12s 6s/step - loss: -0.9689
# Epoch 64/64
# sl slice(3000, 6000, None)
# 1/2 [==============>...............] - ETA: 4s - loss: -0.9715counter 70
# Inside On epoch end
# counter 1
# sl slice(0, 3000, None)
# sl slice(0, 5749, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.9663, 0.7973]
# 2/2 [==============================] - 12s 6s/step - loss: -0.9701
# Prediction(best valid epoch)
# counter 1
# sl slice(0, 5749, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.9016, 0.8019]
# Prediction(best run)
# counter 1
# sl slice(0, 5749, None)
# counter 1
# sl slice(0, 1500, None)
# [Train, Valid]=[0.9757, 0.8188]

# %%
tsk.model.load_weights(bestwfname)
tsk.eval_model1()
# Out:
# counter 1
# sl slice(0, 1379, None)
# [Test]=[0.7701]
# (0.7701,)
